# %% [markdown]
# # Quiz 1: Notes

# %%
# print "name" and "hello world"

print('Hello, World!')

name = "Carol Kao"
print(name)
# Out:
# Hello, World!
# Carol Kao

# %% [markdown]
# # Lecture 2

# %%
# Import packages

#  "matplotlib.pyplot" > "plt"
#  "pandas" >  "pd"

import matplotlib.pyplot as plt
import pandas as pd

# Open datasets
# store datasets in the working event name "carfeatures"
carfeatures = pd.read_csv("/Users/carolkao/Documents/GitHub/qtm151/lectures/lecture-02/data/features.csv")

# We use square brackets [...] to subset information from data 
# Text/strings have to be written in quotation marks
# This command extracts the column 'cylinders'

carfeatures['cylinders']

# compute a frequency table
table = pd.crosstab(index = carfeatures['cylinders'], columns = "count")
table

# rename the column
table.columns.name = 'column name'
table

# computes the count, mean, std, min, 25% quantile, 50%, 75%, max
carfeatures.describe()

# Display a Scatterplot
plt.scatter(x = carfeatures['weight'], y = carfeatures['mpg'])
plt.show()

# %% [markdown]
# Example:
# - Create a new object called
#
# list_datasets = ["features.csv","worlbank_wdi_2019.csv"]
#
# - Run a for loop over this list:
# - Read each of the datasets using "pd.read_csv()"
# - Print a table of descriptive statistics for each dataset

# %%
# Write down your own code:

features = pd.read_csv("/Users/carolkao/Documents/GitHub/qtm151/lectures/lecture-06/data/features.csv")
wdi = pd.read_csv("/Users/carolkao/Documents/GitHub/qtm151/lectures/lecture-06/data/worldbank_wdi_2019.csv")
list_datasets = ["features.csv" , "worlbank_wdi_2019.csv"]
list_datasets
# Out:
# ['features.csv', 'worlbank_wdi_2019.csv']

# %%
for i in range(len(list_datasets)):
    print("The" + " " + str(i+1) + " dataset is" + " " + list_datasets[i])
# Out:
# The 1 dataset is features.csv
# The 2 dataset is worlbank_wdi_2019.csv

# %%
features.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.427136  2970.424623     15.568090
# std      7.815984    1.701004    104.268683   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000

# %%
wdi.describe()
# Out:
#        life_expectancy  gdp_per_capita_usd
# count       252.000000          255.000000
# mean         72.682931        17230.949757
# std           7.382636        25792.183785
# min          52.910000          216.972968
# 25%          67.109750         2186.046581
# 50%          73.599000         6837.717826
# 75%          78.234892        19809.323135
# max          85.078049       199377.481800

# %% [markdown]
# # Lecture 3

# %%
# Identify the type of object
## interger
type(3)
## float
type(3.5)
##string
type("Danilo's car")

# store variable by using "="
# We can then access the value of `x` by typing `x`
## Please note: 
### Variable names are case-sensitive
### Variable names cannot start with a number
### Variable names cannot contain spaces
### Variable names cannot contain special characters, except for `_`

number3 = 3
print(number3)
# Out:
# 3

# %%
# Addition (+), Multiplication (*), Subtraction (-), Division (/), Exponentiation (**)
# Basic operations on numbers
print(3*2)
print(3+2)
print(3-2)
print(3/2)
print(3**2)

#Addition on strings
name = str("Carol")
major = str("BBA + QSS")


"My name is" + " "  + name
"My major is" + " "  + major

# print string and integer together
print("hello" + " " + str(number3))
# Out:
# 6
# 5
# 1
# 1.5
# 9
# hello 3

# %%
# store list
## indexes start at 0

# List of numbers
list_numbers = [1,2,3,4,5]
list_numbers_sqr = [1,4,9,16,25]

# List with strings
list_colors = ["red","yellow","yellow", "green","red"]

# List with mixed types
list_mixed = ["red",1,"yellow",4,5, 3.5]

# extract first element in the list
list_mixed[0]

# add new element in the list
new_list = list_mixed + ['red']
new_list
# Out:
# ['red', 1, 'yellow', 4, 5, 3.5, 'red']

# %%
# Visualizing Lists: Categorical Data
## Histogram
list_list = list_colors + ['red']
list_list 
plt.hist(x = list_list)
# Out:
# (array([3., 0., 0., 0., 0., 2., 0., 0., 0., 1.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
# Visualizing Lists: Continuous Data
## Scatterplot
print(list(list_numbers))
print(list_numbers_sqr)

plt.scatter(x = list_numbers, y = list_numbers_sqr)
plt.xlabel("A meaningful name for the X-axis")
plt.ylabel("Favourite name for Y-axis")
plt.show()
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]

# %% [markdown]
# # Lecture 04: Mathematical Operations and Random Numbers

# %%
# the "numPy" library is used for mathematical operations
# the "matplotlib" library is for generating graphs

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Computes "pi" (3.14...)

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# # compute $ ln(x), e^x, sin(x), cos(x), \sqrt{x}$

# %%
# x = 1
print(np.log(1))
print(np.exp(1))
print(np.sin(1))
print(np.cos(1))
print(np.sqrt(1))
# Out:
# 0.0
# 2.718281828459045
# 0.8414709848078965
# 0.5403023058681398
# 1.0

# %% [markdown]
# # compute exponentials: $ x^5 $

# %%
x = 10
x ** 5
# Out:
# 100000

# %% [markdown]
# # Vector Arrays
# - NumPy arrays are created using the `np.array()` function
# - We can create arrays from lists
# - We can also create arrays with a sequence of numbers using `np.arange()`
# - We can create arrays with zeros or ones using `np.zeros()` and `np.ones()`

# %%
vec_a  = np.array([1,2,3])
vec_b  = np.array([0,1,0])
vec_c  = np.array([10,100,1000,2000,5000])

# display
print(vec_a)

# extract the second element from the vector a
print(vec_a[1])
# Out:
# [1 2 3]
# 2

# %%
# operations with a single array and scalar
print(vec_a * 2)
print(vec_a / 2)
print(vec_a + 2)
print(vec_a ** 2)

# addition, mutiplication, subtraction between two arrays of the same size
## Make sure two arrays have same size
print(vec_a + vec_b)
print(vec_a * vec_b)
print(vec_a - vec_b)

# summary of statistics of an array
print(np.mean(vec_a))
print(np.std(vec_a))
print(np.min(vec_a))
print(np.median(vec_a))
print(np.max(vec_a))
# Out:
# [2 4 6]
# [0.5 1.  1.5]
# [3 4 5]
# [1 4 9]
# [1 3 3]
# [0 2 0]
# [1 1 3]
# 2.0
# 0.816496580927726
# 1
# 2.0
# 3

# %% [markdown]
# # Matrix Operations

# %%
# Matrices are usually denoted by capital letters

# row vectors
X = np.array([[1,2,3],[0,4,5],[0,0,6]])
print(X)

# column vectors
Y =  np.column_stack([[1,0,1],[2,1,0]])
print(Y)

# Matrix Transpose
np.matrix.transpose(Y)

# Matrix Multiplication

np.dot(X,Y)
np.matmul(X,Y)

# Matrix Inverse
## Check the determinant of a matrix 
print(np.linalg.det(X))
## Inverse
X_inv = np.linalg.inv(X)
print(X_inv)
# Out:
# [[1 2 3]
#  [0 4 5]
#  [0 0 6]]
# [[1 2]
#  [0 1]
#  [1 0]]
# 23.999999999999993
# [[ 1.         -0.5        -0.08333333]
#  [ 0.          0.25       -0.20833333]
#  [ 0.          0.          0.16666667]]

# %% [markdown]
# # Random Variables

# %%
# create a vector of random variables

## generated from a normal distribution 
## mean "loc" (location) and standard deviation "scale"
## the number of distinct variables is "size"

randomvar_a = np.random.normal(loc=0, scale=1, size=10)
print(randomvar_a)

# create a "pre-generated" random variables list
np.random.seed(12345)

random_var_b = np.random.normal(loc=0, scale=1, size=10)
print(random_var_b)
# Out:
# [-1.41537074 -0.42064532 -0.34271452 -0.80227727 -0.16128571  0.40405086
#   1.8861859   0.17457781  0.25755039 -0.07444592]
# [-0.20470766  0.47894334 -0.51943872 -0.5557303   1.96578057  1.39340583
#   0.09290788  0.28174615  0.76902257  1.24643474]

# %%
# Compute a histogram
randomvar_x = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(x = randomvar_x)
plt.xlabel("Variable a")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Boolean Variables and If/Else Statements
#
# Single (=) vs Double (==)
#
# When you have a single equality (=) you are assignning the variable
#
# When you have a double equality (==) you are comparing two values

# %%
# Test Equality of string (==)
any_questions = "no"
print( any_questions == "no" )

# Test for the presence of keywords in a sentence (in)
current_month  = "September"

list_summer_months = ["June","July","August"]

print(current_month in list_summer_months)
print('June' in list_summer_months)

# Test Expressions with Number
## Strictly less than (<), less than or equal (<=)
## Equal (==)
## Strictly more than (>), greater than or equal to (>=)
x = 5

print( x < 5 )
print( x <= 5 )
print( x == 5 )
print( x >= 5 )
print( x > 5 )
# Out:
# True
# False
# True
# False
# True
# True
# True
# False

# %% [markdown]
# Condition A <span style="color:red"> and </span> Condition B need to be satisfied: &

# %%
age = 31

# Is this age between 20 and 30 (including these ages)?
( age >= 20 ) & (age <= 30)
# Out:
# False

# %% [markdown]
# Condition A <span style="color:red"> or </span> Condition B need to be satisfied: |

# %%
student_status = "freshman" 

# Is the student in the first two years of undergrad?
(student_status == "freshman") | (student_status == "sophomore")
# Out:
# True

# %% [markdown]
# Flow Control (if/elif/else)

# %%
# example 1:
years_in_program = 1

if years_in_program == 1:
    print("This student is a freshman")
elif years_in_program == 2:
    print("This student is a sophomore")
elif years_in_program == 3:
    print("This student is a junior")
else:
    print("This student is a senior")


#  example 2:
# Creating the variable "points" and assigning a value between 0 and 100
points = 85  

# Using if, elif, and else to assign the letter grade
if points >= 90:
    letter_grade = 'A'
elif points >= 80:
    letter_grade = 'B'
elif points >= 70:
    letter_grade = 'C'
elif points >= 60:
    letter_grade = 'D'
else:
    letter_grade = 'F'

# Printing the letter grade
letter_grade
# Out:
# This student is a freshman
# 'B'

# %% [markdown]
# # Lecture 5: Optional Appendix while using loop

# %%
# use "append" for iterations
## e as the threshold

e = 0.01

x_list = []
y_list = []

print(x_list)

x = 1
while 1/x > e:
    x_list.append(x)
    y_list.append(1/x)
    x = x + 1

plt.scatter(x= x_list, y = y_list)
plt.title("Graph of f(x) = 1/x")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# []
# Text(0, 0.5, 'y')

# %% [markdown]
# # For Loop
# list_name = [ expression for value in list_values]

# %%
# Example 1: Customized Messages

id_list = ["KIA", "Ferrari", "Ford", "Tesla"]
message_list = ["Your car model is :" + id for id in id_list]

print(message_list)
# Out:
# ['Your car model is :KIA', 'Your car model is :Ferrari', 'Your car model is :Ford', 'Your car model is :Tesla']

# %%
# Example 2: Customized Message + Numering

topic_list   = ["Python", "Python","SQL"]
module_list  = ["One", "Two", "Three"]

num_topics = len(topic_list)

message_list = [" Module " + module_list[i] + " will cover " + topic_list[i] for i in range(num_topics)]
print(message_list)
# Out:
# [' Module One will cover Python', ' Module Two will cover Python', ' Module Three will cover SQL']

# %%
# Example 3: Math operations
x_list = [ 1,2,3,4,5,6,7  ]

x_sqr_list = [ x**2 for x in x_list ]
x_sqr_list
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %% [markdown]
# Interrupt For Loop: Skipping iterations (combine with if/else )

# %%
# The isinstance(value,int) function checks whether "value" is an integer.UserWarning
# use "continue" to skill the remainder of any iteration 

list_mixed = [1,2,"text_message",5]

for value in list_mixed:
    if(not isinstance(value,int)):
        continue
    print(value)
# Out:
# 1
# 2
# 5

# %%
# use "break" to stop the loop altogether

list_mixed = [1,2,"text_message",5]

for value in list_mixed:
    if(not isinstance(value,int)):
        print("Stopped: There is an element in your list that isn't an integer")
        break
    print(value)
# Out:
# 1
# 2
# Stopped: There is an element in your list that isn't an integer

# %% [markdown]
# # Lecture 6: Loops

# %% [markdown]
# # Manipulating Lists

# %%
# Null List
list_answers = [None,None,None]
print(list_answers)


# assigning/ replacing values to lists
list_answers[0] = "Nashville"
list_answers


# Appending values to lists
new_list = []
new_list.append("Nashville")
new_list.append("Bogota")
# new_list.append()
print(new_list)


# Lists with repeated values
## Repeat a single value 30 times
list_two_rep = [7] * 30
## Repeat a list 4 times
list_answers_rep = list_answers * 4 
## Repeat of 8 null values
list_none_rep = [None] * 8 

print(list_two_rep)
print(list_answers_rep)
print(list_none_rep)
# Out:
# [None, None, None]
# ['Nashville', 'Bogota']
# [7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# ['Nashville', None, None, 'Nashville', None, None, 'Nashville', None, None, 'Nashville', None, None]
# [None, None, None, None, None, None, None, None]

# %% [markdown]
# # Multiplying lists vs multiplying arrays

# %%
# When you multipy a list times a number you repeat the list
list_a = [1,2,3]
print( list_a*4)

# When you multipy an array times a number, you multiply each element
vec_a = np.array(list_a)
print( vec_a * 4)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]
# [ 4  8 12]

# %% [markdown]
# # count length of vectors

# %%
# use len() to count the number of elements in a vector

print(len(list_answers))
print(len(list_two_rep))
print(len(list_answers_rep))
# Out:
# 3
# 30
# 12

# %% [markdown]
# # Customized Messages + Numbering

# %%
# method 1:

list_ids = ["KIA", "Ferrari", "Ford", "Tesla"]

index = 1
print('We are out of the loop', index)
for id in list_ids:
    print("Dear customer, your position is " + str(index) + " on the waitlist" +
           " and your car brand is " + id )
    index = index + 1
    print('We are inside the loop', index)

# method 2:
for i in range(len(list_ids)):
    print("Dear customer, your position is " + str(i+1) + " on the waitlist" +
           " and your car brand is " + list_ids[i])
# Out:
# We are out of the loop 1
# Dear customer, your position is 1 on the waitlist and your car brand is KIA
# We are inside the loop 2
# Dear customer, your position is 2 on the waitlist and your car brand is Ferrari
# We are inside the loop 3
# Dear customer, your position is 3 on the waitlist and your car brand is Ford
# We are inside the loop 4
# Dear customer, your position is 4 on the waitlist and your car brand is Tesla
# We are inside the loop 5
# Dear customer, your position is 1 on the waitlist and your car brand is KIA
# Dear customer, your position is 2 on the waitlist and your car brand is Ferrari
# Dear customer, your position is 3 on the waitlist and your car brand is Ford
# Dear customer, your position is 4 on the waitlist and your car brand is Tesla

# %% [markdown]
# # Plots for Multiple Variables

# %%
carfeatures = pd.read_csv("/Users/carolkao/Documents/GitHub/qtm151/lectures/lecture-06/data/features.csv")
list_vars   = ["acceleration","weight"]

for variable_name in list_vars:
    plt.scatter(x= carfeatures[variable_name], y = carfeatures["mpg"])
    plt.ylabel("mpg")
    plt.xlabel(variable_name)
    plt.show()

# %%
carfeatures = pd.read_csv("/Users/carolkao/Documents/GitHub/qtm151/lectures/lecture-06/data/features.csv")
list_vars   = ["acceleration","weight"]

index = 1
for variable_name in list_vars:
    plt.scatter(x= carfeatures[variable_name], y = carfeatures["mpg"])
    plt.ylabel("mpg")
    plt.xlabel(variable_name)
    plt.title("Figure " + str(index))
    plt.show()
    index = index + 1

# %% [markdown]
# # Math Operations + Numbering (Filling)
#
# # $ y = x^2 + 2x$

# %%
# Create a list of x-values list_x = [1,2,4,5, ..., 50]
# Start an empty list of y-values with []

list_x = [1,2,4,5,6,7,8,9,10]
list_y = []

# Create an index 
for x in list_x:
    y = x**2 + 2*x
    list_y.append(y)

# Display results visually
print(list_y)
plt.scatter(list_x, list_y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# [3, 8, 24, 35, 48, 63, 80, 99, 120]
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# # Lecture 7: Simulation Studies

# %%
# Visualing Random Variables in different distributions
## Consider a sample with n observations

# Set Sample size 
# These produce several common distributions
# A normam with "loc" and standard deviation "5"
# A chi-square with "df" degrees of freedom
# A uniform with values between -3 and 5

n = 10000

vec_normal  = np.random.normal(loc = 7, scale = 5, size = n)
vec_chisqr  = np.random.chisquare(df = 1, size = n)
vec_unif    = np.random.uniform(low = -3,high = 5, size = n)

# same average
print(vec_normal.mean())
print(vec_chisqr.mean())
print(vec_unif.mean())
# Out:
# 6.937850972684668
# 1.0021447118250841
# 0.9979063988586531

# %% [markdown]
# <font size = "4" >
#
# Multiple plots in a row (subplot)
#
# - The normal has more of a bell shape
# - The uniform is a rectangular shape

# %%
#------------------------ Setting up subplots----------------------------------#
# Create a plot with 1 row, 2 columns
# You will create a list of subfigures "list_subfig"
# The option "figsize" indicates the (width,height)) of the graph
fig, list_subfig = plt.subplots(1, 3,figsize = (12,4))


# The tight layout option ensures that the axes are not overlapping
plt.tight_layout()

# First Figure
list_subfig[0].hist(x = vec_normal)
list_subfig[0].set_title("Normal Distribution")
list_subfig[0].set_xlabel("Value")
list_subfig[0].set_ylabel("Frequency")

# Second Figure
list_subfig[1].hist(x = vec_unif)
list_subfig[1].set_title("Uniform Distribution")
list_subfig[1].set_xlabel("Value")
list_subfig[1].set_ylabel("Frequency")

# Third Figure
list_subfig[2].hist(x=vec_chisqr)
list_subfig[2].set_title("Chi-Square Distribution")
list_subfig[2].set_xlabel("Value")
list_subfig[2].set_ylabel("Frequency")

# Note:
# Use the set_title() function for the title of subfigures
# Similarly, use "set_xlabel()" and "set_ylabel()"
# Out:
# Text(769.1928104575164, 0.5, 'Frequency')

# %% [markdown]
# # Single Loop

# %%
# list(range(start, stop, step))
# step is gap between each number in the sequence
list(range(1,9,2))
# Out:
# [1, 3, 5, 7]

# %%
# We will draw random sample "num_simulations" times
# Each time we will create a random vector of size "sample_size"
# In this example we will generate values from a uniform between -2 and 2.

num_simulations = 2000
sample_size     = 100

vec_xbar = [None] * num_simulations

for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()

vec_xbar

plt.hist(vec_xbar)
plt.title("Distribution of Xbar with different simulated samples")
plt.ylabel("Frequency")
plt.xlabel("Values of Xbar")
plt.show()

# %% [markdown]
# # Nested Loop

# %%
# To evaluate different sample size which just have to write a for-loop within 
# another for-loop

num_simulations = 2000
sample_size_list = [1,10,50,100,200]

for sample_size in sample_size_list:

    # The following command a vector null values, of length "num_simulations"
    vec_xbar = [None] * num_simulations
    
    for iteration in range(num_simulations):
            vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
            vec_xbar[iteration] = vec_unif.mean()
    plt.hist(vec_xbar)
    plt.title("Distribution of Xbar when n is " + str(sample_size))
    plt.ylabel("Frequency")
    plt.xlabel("Values of Xbar")
    plt.show()

# %% [markdown]
# # Fuctions
#
# "Built-in" functions are those from Python libraries, e.g.
#
# ```print()```, ```type()```, ```round()```,```abs()```, ```len()```

# %%
# Argument:   "Hello" 
# Return:     Showing the message on screen

print("Hello "+str(24))
# Out:
# Hello 24

# %%
# Argument:  3.14
# Return:    The type of object, e.g. int, str, boolean, float, etc.

type("ABC")
# Out:
# str

# %%
# First Argument:   np.pi     (a numeric value)
# Second Argument:  6         (the number of decimals)
# Return:  Round the first argument, given the number of decimals in the second argument

round(np.pi, 6)
# Out:
# 3.141593

# %%
# Argument: -4
# Return:   The absolute value
abs(-4)
# Out:
# 4

# %%
list_fruits = ["Apple","Orange","Pear"]

# Argument: list_fruits
# Return:   The number of elements in the list
len(list_fruits)
# Out:
# 3

# %% [markdown]
# <font size = "1.5">
#
# # Enter Arguments by assigning parameters

# %%
# Here "df" and "size" are both parameters
# They get assigned the arguments "2" and "20", respectively
# The return is a vector of random variables

vec_x = np.random.chisquare(df = 2, size = 20)
vec_y = np.random.normal(loc = 2, scale = 1, size = 20)
vec_z = np.random.uniform(low = -2, high =2, size = 50)

vec_x
vec_y
vec_z
# Out:
# array([ 1.37444023e+00,  1.92972724e+00,  1.05727183e+00, -4.00208394e-01,
#        -1.23596948e+00,  1.41934557e+00, -9.10623695e-02, -8.03406434e-01,
#         1.96374693e+00,  1.67157396e+00,  1.44184689e+00, -1.89869016e+00,
#        -1.01102499e+00,  1.88504302e+00,  8.11163013e-01,  1.83916460e-01,
#        -1.38500405e+00,  1.98948421e-01,  1.30900681e-01,  1.55086530e+00,
#         1.79235652e+00,  1.43589199e+00, -1.61678218e+00, -1.07179818e+00,
#         4.44479978e-01,  1.20493679e+00,  6.11652737e-01,  5.25321196e-01,
#        -6.56601955e-01,  1.94124861e+00,  6.13300730e-01,  1.47161692e+00,
#         1.13182375e+00, -1.62232722e+00, -3.35320238e-04,  1.84709043e+00,
#        -7.80114444e-02,  1.50430623e+00, -6.13486938e-01, -2.49432111e-01,
#        -1.96840769e+00, -1.74555959e+00, -1.43966813e+00, -1.74016782e+00,
#        -1.66259758e+00,  8.28057817e-01, -4.22163637e-01,  1.48447356e+00,
#         8.85286902e-02,  7.69717216e-01])

# %% [markdown]
# <font size = "3">
#
# Example: Calculate
#
# $V=P\left(1+{\frac {r}{n}}\right)^{nt}$

# %%
# We are going to define a function "fn_compute_value"
# You can choose any name
# Using prefixes like "fn_" can help you remember this is a "function" object
# What are the parameters?

def function_v(P, r,n, t):
    v = P*(1+(r/n))**(n*t)
    return v

# %%
function_v(P=100, r = 0.01, n = 20, t=10)
# Out:
# 110.51432983541218

# %%
# You can know compute the formula with different values

V1 = function_v(P = 1000, r = 0.01, n = 20, t=10)
V2 = function_v(P = 10, r = 0.01, n = 20, t=10)

print(V1)
print(V2)
# Out:
# 1105.1432983541217
# 11.051432983541218

# %% [markdown]
# # Local and Global Variables
#
# <font size = "5">
#
# Any "global" variable can be referenced inside functions
#
# - However, this can lead to mistakes
# - Preferrably, include **all** the inputs as parameters

# %%
# Example 1 (define F(x, y, z) = x + y + z)
def fn_add_recommended(x,y,z):
    return(x + y + z)

print(fn_add_recommended(x = 1, y = 2, z = 5))
print(fn_add_recommended(x = 1, y = 2, z = 10))
# Out:
# 8
# 13

# %% [markdown]
# <font size ="5">
#
# Variables defined inside functions are "local"
#
# - Stored "temporarily" while running
# - Includes: Parameters + Intermediate variables

# %%
def fn_square(x):
    y = x**2
    return(y)

print(fn_square(x=5))
# Out:
# 25

# %% [markdown]
# <font size = "5">
#
# Local variables are **not** stored in the working environment

# %%
x = 5
y = 4

print("Example 1:")
print(fn_square(x = 10))
print(x)
print(y)

print("Example 2:")
print(fn_square(x = 20))
print(x)
print(y)
# Out:
# Example 1:
# 100
# 5
# 4
# Example 2:
# 400
# 5
# 4

# %% [markdown]
# <font size = "5">
#
# To permanently modify a variable, use the "global" command

# %%
def modify_x():
    global x
    x = x + 5

x = 1
# Now, running the function wil permanently increase x by 5.
modify_x()
print(x)

def modify_y():
    global y
    y = y/2

y = 20
modify_y()
print(y)
# Out:
# 6
# 10.0

# %% [markdown]
# <font size = "6" >
# Operations Over Data Fram

# %% [markdown]
# <font size = "5">
#
# Create an empty data frame

# %%
data  = pd.DataFrame()
print(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# <font size = "4">
# Add Variables

# %%
data["age"] = [18,29,15,32,6]
data["num_underage_siblings"] = [0,0,1,1,0]
data["num_adult_siblings"] = [1,0,0,1,0]

# return the dataframe
data
# Out:
#    age  num_underage_siblings  num_adult_siblings
# 0   18                      0                   1
# 1   29                      0                   0
# 2   15                      1                   0
# 3   32                      1                   1
# 4    6                      0                   0

# %% [markdown]
# <font size = "4">
# Define Functions

# %%
# The first two functions return True/False depending on age constraints
# The third function returns the sum of two numbers
# The fourth function returns a string with the age bracket

fn_iseligible_vote = lambda age: age >= 18

fn_istwenties = lambda age: (age >= 20) & (age < 30)

fn_sum = lambda x,y: x + y

def fn_agebracket(age):
    if (age >= 18):
        status = "Adult"
    elif (age >= 10) & (age < 18):
        status = "Adolescent"
    else:
        status = "Child"
    return(status)

print(fn_agebracket(age=16))
# Out:
# Adolescent

# %% [markdown]
# <font size = "4">
# Applying functions with one argument: <br>
#
# ```python
#  apply(myfunction)
#  ```
#  - Takes a dataframe series (a column vector) as an input
#  - Computes function separately for each individual

# %%
# The fucntion "apply" will extract each element and return the function value
# It is similar to running a "for-loop" over each element

data["can_vote"]    = data["age"].apply(fn_iseligible_vote)
data["in_twenties"] = data["age"].apply(fn_istwenties)
data["age_bracket"] = data["age"].apply(fn_agebracket)


# NOTE: The following code also works:
# data["can_vote"]    = data["age"].apply(lambda age: age >= 18)
# data["in_twenties"] = data["age"].apply(lambda age: (age >= 20) & (age < 30))

display(data)
# Out:
#    age  num_underage_siblings  num_adult_siblings  can_vote  in_twenties  \
# 0   18                      0                   1      True        False
# 1   29                      0                   0      True         True
# 2   15                      1                   0     False        False
# 3   32                      1                   1      True        False
# 4    6                      0                   0     False        False
#
#   age_bracket
# 0       Adult
# 1       Adult
# 2  Adolescent
# 3       Adult
# 4       Child

# %% [markdown]
# <font size = "4">
# Create a New Variable

# %%
data['new_var'] = data['age'].apply(lambda age: age >= 18)
data

data['new_var'] = data['age'].apply(fn_iseligible_vote)
data
# Out:
#    age  num_underage_siblings  num_adult_siblings  can_vote  in_twenties  \
# 0   18                      0                   1      True        False
# 1   29                      0                   0      True         True
# 2   15                      1                   0     False        False
# 3   32                      1                   1      True        False
# 4    6                      0                   0     False        False
#
#   age_bracket  new_var
# 0       Adult     True
# 1       Adult     True
# 2  Adolescent    False
# 3       Adult     True
# 4       Child    False

# %% [markdown]
# <font size = "4">
#
# Dropping an existing variable

# %%
data = data.drop(columns=['new_var'])
data
# Out:
#    age  num_underage_siblings  num_adult_siblings  can_vote  in_twenties  \
# 0   18                      0                   1      True        False
# 1   29                      0                   0      True         True
# 2   15                      1                   0     False        False
# 3   32                      1                   1      True        False
# 4    6                      0                   0     False        False
#
#   age_bracket
# 0       Adult
# 1       Adult
# 2  Adolescent
# 3       Adult
# 4       Child

# %% [markdown]
# <font size = "5">
#
# Mapping functions with one or more arguments <br>
#
# <font size = "4">
# **Definition:** The ```map()``` function executes a <br>
# specified function for each item in an iterable <br>
# (such as a list or an array). <br>
#  The item is sent to the function as a parameter.
#
# ```python
# list(map(myfunction, list1, list2, ....))
# ```

# %%
# We use list() to convert the output to a list
# The first argument of map() is a function
# The following arguments are the subarguments of the function

data["can_vote_map"] = list(map(fn_iseligible_vote, data["age"]))

display(data[["age","can_vote","can_vote_map"]])

## Note: this one also works
data["can_vote_map"] = data["age"].map(lambda age: age >= 18)
# Out:
#    age  can_vote  can_vote_map
# 0   18      True          True
# 1   29      True          True
# 2   15     False         False
# 3   32      True          True
# 4    6     False         False

# %% [markdown]
# <font size = "4">
# Mapping Functions: more than 2 arguments

# %%
# In this example, there are more than two arguments

data["num_siblings"] = list(map(fn_sum,
                                data["num_underage_siblings"],
                                data["num_adult_siblings"]))

display(data[['num_underage_siblings','num_adult_siblings','num_siblings']])
# Out:
#    num_underage_siblings  num_adult_siblings  num_siblings
# 0                      0                   1             1
# 1                      0                   0             0
# 2                      1                   0             1
# 3                      1                   1             2
# 4                      0                   0             0

# %% [markdown]
# <font size = "4">
# Example:
#
# - Map can also be applied to simple lists!
# - Create a lambda function with arguments {fruit,color}.
# - The function returns the string <br>
# " A {fruit} is {color}"
# - Create the following two lists:
#
# ``` list_fruits  = ["banana","strawberry","kiwi"] ```
#
# ``` list_colors  = ["yellow","red","green"] ```
# - Use the list(map()) function to output a list with the form

# %%
# Define the lists
list_fruits = ["banana", "strawberry", "kiwi"]
list_colors = ["yellow", "red", "green"]

# Use map() with a lambda function to format the strings
result = list(map(lambda fruit, color: f"A {fruit} is {color}", list_fruits, list_colors))

# Output the result
print(result)
# Out:
# ['A banana is yellow', 'A strawberry is red', 'A kiwi is green']

# %% [markdown]
# <font size = "5">
# Subsetting Data

# %% [markdown]
# <font size = "4">
# *pandas dataframe*

# %%
# Read the car features dataset
carfeatures = pd.read_csv("/Users/carolkao/Documents/GitHub/qtm151/lectures/lecture-11/data_raw/features.csv")

# The display() command will show the first 5 rows and the last five rows
display(carfeatures)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 0    18.0          8           307        130    3504          12.0  C-1689780
# 1    15.0          8           350        165    3693          11.5  B-1689791
# 2    18.0          8           318        150    3436          11.0  P-1689802
# 3    16.0          8           304        150    3433          12.0  A-1689813
# 4    17.0          8           302        140    3449          10.5  F-1689824
# ..    ...        ...           ...        ...     ...           ...        ...
# 393  27.0          4           140         86    2790          15.6  F-1694103
# 394  44.0          4            97         52    2130          24.6  V-1694114
# 395  32.0          4           135         84    2295          11.6  D-1694125
# 396  28.0          4           120         79    2625          18.6  F-1694136
# 397  31.0          4           119         82    2720          19.4  C-1694147
#
# [398 rows x 7 columns]

# %% [markdown]
# <font size = "4" >
#
# Extract column names

# %%
type(carfeatures.columns.values)

# Write the name of the dataset and use a period "." to extract 
# the attribute "columns" and the subttribute "values"

car_colnames = carfeatures.columns.values
print(car_colnames)
# Out:
# ['mpg' 'cylinders' 'displacement' 'horsepower' 'weight' 'acceleration'
#  'vehicle_id']

# %% [markdown]
# <font size = "4">
#
# Subset columns:
#
# ```python
# data[list_names]
# ```

# %%
carfeatures[car_colnames[0]]

# NOTE same as:
carfeatures['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
# write the name of the datasets >> subset multiple columns 

list_subsetcols = ["weight","mpg"]
subcols_carfeatures = carfeatures[list_subsetcols]
display(subcols_carfeatures)

# Or we can simply include the list directly inside square brackets
display(carfeatures[["weight","mpg"]])
# Out:
#      weight   mpg
# 0      3504  18.0
# 1      3693  15.0
# 2      3436  18.0
# 3      3433  16.0
# 4      3449  17.0
# ..      ...   ...
# 393    2790  27.0
# 394    2130  44.0
# 395    2295  32.0
# 396    2625  28.0
# 397    2720  31.0
#
# [398 rows x 2 columns]
#      weight   mpg
# 0      3504  18.0
# 1      3693  15.0
# 2      3436  18.0
# 3      3433  16.0
# 4      3449  17.0
# ..      ...   ...
# 393    2790  27.0
# 394    2130  44.0
# 395    2295  32.0
# 396    2625  28.0
# 397    2720  31.0
#
# [398 rows x 2 columns]

# %% [markdown]
# <font size = "4">
# subsetting by rows/ columns

# %%
carsorted = carfeatures.sort_values(by = "mpg", ascending = False)
display(carsorted)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 322  46.6          4            86         65    2110          17.9  M-1693322
# 329  44.6          4            91         67    1850          13.8  H-1693399
# 325  44.3          4            90         48    2085          21.7  V-1693355
# 394  44.0          4            97         52    2130          24.6  V-1694114
# 326  43.4          4            90         48    2335          23.7  V-1693366
# ..    ...        ...           ...        ...     ...           ...        ...
# 103  11.0          8           400        150    4997          14.0  C-1690913
# 67   11.0          8           429        208    4633          11.0  M-1690517
# 25   10.0          8           360        215    4615          14.0  F-1690055
# 26   10.0          8           307        200    4376          15.0  C-1690066
# 28    9.0          8           304        193    4732          18.5  H-1690088
#
# [398 rows x 7 columns]

# %% [markdown]
# <font size = "4">
#
# Subset row(s)
#
# ``` data.iloc[ row_int , : ]``` $\quad$ or
#
# ``` data.iloc[ list_rows, : ]```

# %%
# subsetting first three rows
carsorted.iloc[[0,1,2]]
carfeatures.iloc[[0,1,2]]
# NOTE same as:
display(carsorted.iloc[[0,1,2],:])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 322  46.6          4            86         65    2110          17.9  M-1693322
# 329  44.6          4            91         67    1850          13.8  H-1693399
# 325  44.3          4            90         48    2085          21.7  V-1693355

# %%
# Extracts all columns for row zero
# In this case we will show the car with the highest "mpg" value

display(carsorted.iloc[0,:])
# Out:
# mpg                  46.6
# cylinders               4
# displacement           86
# horsepower             65
# weight               2110
# acceleration         17.9
# vehicle_id      M-1693322
# Name: 322, dtype: object

# %% [markdown]
# <font size = "4">
#
# Subset block of rows
#
# ``` data.iloc[ lower:upper , : ]```
#
# - One column: $\quad$ ``` data.iloc[ : , col_integer ]```
# - Multiple columns: $\quad$ ``` data.iloc[ : , list_cols ]```
# - Row+Column: $\quad$ ``` data.iloc[ list_rows , list_cols ]```

# %%
# Extract rows 0 to 5
display(carfeatures.iloc[0:5,:])

# Extract rows 8 onwards
display(carfeatures.iloc[:8, : ])

# Note: We can leave the numbers to the left and right of ":" blank
# in order to select all values before or after, respectively.

display(carfeatures.iloc[:,[0,1,2]])
display(carfeatures.iloc[[0,1,2],[0,1,2]])
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 0  18.0          8           307        130    3504          12.0  C-1689780
# 1  15.0          8           350        165    3693          11.5  B-1689791
# 2  18.0          8           318        150    3436          11.0  P-1689802
# 3  16.0          8           304        150    3433          12.0  A-1689813
# 4  17.0          8           302        140    3449          10.5  F-1689824
#     mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 0  18.0          8           307        130    3504          12.0  C-1689780
# 1  15.0          8           350        165    3693          11.5  B-1689791
# 2  18.0          8           318        150    3436          11.0  P-1689802
# 3  16.0          8           304        150    3433          12.0  A-1689813
# 4  17.0          8           302        140    3449          10.5  F-1689824
# 5  15.0          8           429        198    4341          10.0  F-1689835
# 6  14.0          8           454        220    4354           9.0  C-1689846
# 7  14.0          8           440        215    4312           8.5  P-1689857
#       mpg  cylinders  displacement
# 0    18.0          8           307
# 1    15.0          8           350
# 2    18.0          8           318
# 3    16.0          8           304
# 4    17.0          8           302
# ..    ...        ...           ...
# 393  27.0          4           140
# 394  44.0          4            97
# 395  32.0          4           135
# 396  28.0          4           120
# 397  31.0          4           119
#
# [398 rows x 3 columns]
#     mpg  cylinders  displacement
# 0  18.0          8           307
# 1  15.0          8           350
# 2  18.0          8           318

# %% [markdown]
# <font size = "5">
# Filtering Dataframes Based on Logical Expressions

# %% [markdown]
# <font size = "4">
#
# Filtering using ```pandas.query()```
#
# ```python
# data.query("logical expression")
# ```

# %%
# Filter cars with mpg >=25
carfeatures.query("mpg >= 25")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 18   27.0          4            97         88    2130          14.5  D-1689978
# 19   26.0          4            97         46    1835          20.5  V-1689989
# 20   25.0          4           110         87    2672          17.5  P-1690000
# 22   25.0          4           104         95    2375          17.5  S-1690022
# 23   26.0          4           121        113    2234          12.5  B-1690033
# ..    ...        ...           ...        ...     ...           ...        ...
# 393  27.0          4           140         86    2790          15.6  F-1694103
# 394  44.0          4            97         52    2130          24.6  V-1694114
# 395  32.0          4           135         84    2295          11.6  D-1694125
# 396  28.0          4           120         79    2625          18.6  F-1694136
# 397  31.0          4           119         82    2720          19.4  C-1694147
#
# [169 rows x 7 columns]

# %%
# Use "and" / "or" for logical operations on queries
carfeatures.query("(acceleration >= 10) and (acceleration < 18)")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 0    18.0          8           307        130    3504          12.0  C-1689780
# 1    15.0          8           350        165    3693          11.5  B-1689791
# 2    18.0          8           318        150    3436          11.0  P-1689802
# 3    16.0          8           304        150    3433          12.0  A-1689813
# 4    17.0          8           302        140    3449          10.5  F-1689824
# ..    ...        ...           ...        ...     ...           ...        ...
# 390  32.0          4           144         96    2665          13.9  T-1694070
# 391  36.0          4           135         84    2370          13.0  D-1694081
# 392  27.0          4           151         90    2950          17.3  C-1694092
# 393  27.0          4           140         86    2790          15.6  F-1694103
# 395  32.0          4           135         84    2295          11.6  D-1694125
#
# [315 rows x 7 columns]

# %% [markdown]
# <font size = "4">
# Expressions with colnames + global variables (@)

# %%
# invoke global variables into the query by using @variablename
# create a global variable @threshold
threshold = 25

# filter cars with mpg >= threshold
data_varthreshold_mpg = carfeatures.query("mpg >= @threshold")

# NOTE same as:
carfeatures[carfeatures['mpg']>=threshold]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 18   27.0          4            97         88    2130          14.5  D-1689978
# 19   26.0          4            97         46    1835          20.5  V-1689989
# 20   25.0          4           110         87    2672          17.5  P-1690000
# 22   25.0          4           104         95    2375          17.5  S-1690022
# 23   26.0          4           121        113    2234          12.5  B-1690033
# ..    ...        ...           ...        ...     ...           ...        ...
# 393  27.0          4           140         86    2790          15.6  F-1694103
# 394  44.0          4            97         52    2130          24.6  V-1694114
# 395  32.0          4           135         84    2295          11.6  D-1694125
# 396  28.0          4           120         79    2625          18.6  F-1694136
# 397  31.0          4           119         82    2720          19.4  C-1694147
#
# [169 rows x 7 columns]

# %% [markdown]
# <font size = "4">
#
# Expressions with colnames with spaces

# %%
# Sometimes column names have spaces in them
# In this case use the "`" symbol, e.g.          `variable name`

carfeatures["new variable"] = carfeatures["mpg"]
data_spacesthreshold_mpg = carfeatures.query("`new variable` >= 25")
data_spacesthreshold_mpg
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 18   27.0          4            97         88    2130          14.5
# 19   26.0          4            97         46    1835          20.5
# 20   25.0          4           110         87    2672          17.5
# 22   25.0          4           104         95    2375          17.5
# 23   26.0          4           121        113    2234          12.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4           140         86    2790          15.6
# 394  44.0          4            97         52    2130          24.6
# 395  32.0          4           135         84    2295          11.6
# 396  28.0          4           120         79    2625          18.6
# 397  31.0          4           119         82    2720          19.4
#
#     vehicle_id  new variable
# 18   D-1689978          27.0
# 19   V-1689989          26.0
# 20   P-1690000          25.0
# 22   S-1690022          25.0
# 23   B-1690033          26.0
# ..         ...           ...
# 393  F-1694103          27.0
# 394  V-1694114          44.0
# 395  D-1694125          32.0
# 396  F-1694136          28.0
# 397  C-1694147          31.0
#
# [169 rows x 8 columns]

# %% [markdown]
# <font size = "5">
# Visualisation for Subsets of the Data

# %% [markdown]
# <font size = "4">
# Compute Two Overlapping Plots

# %%
# Use pd.unique() to extract a list with the unique elements in that column
list_unique_cylinders = pd.unique(carfeatures["cylinders"])
print(list_unique_cylinders)

# If we call plt.scatter() twice to display two plots
# The idea is that the graphs are stacked on top of each other

df_8 = carfeatures.query("cylinders == 8")
df_4 = carfeatures.query("cylinders == 4")

plt.scatter(x = df_8["weight"],y = df_8["acceleration"])
plt.scatter(x = df_4["weight"],y = df_4["acceleration"])
plt.legend(labels = ["8","4"],
           title  = "Cylinders")

# Display all plots simultaneously
# Note: plt.show() >> the results will be shown on separate graphs instead
plt.show()
# Out:
# [8 4 6 3 5]

# %% [markdown]
# <font size = "4" >
# Compute Plots by All Categories

# %%
# Compute number of unique categories
list_unique_cylinders = pd.unique(carfeatures["cylinders"])

# Use a for loop to plot a scatter plot between "weight" and "acceleration"
# for each category. Each plot  will have a different color

for category in list_unique_cylinders:
    df   = carfeatures.query("cylinders == @category")
    plt.scatter(x = df["weight"],y = df["acceleration"])
    
# Add labels and a legends    
plt.xlabel("Weight")
plt.ylabel("Acceleration")
plt.legend(labels = list_unique_cylinders,
           title  = "Cylinders")
plt.show()

# %% [markdown]
# <font size = "4">
# Filtering Dataframes Based on Logical Expressions

# %%
# Using the Square Bracket Operator
carfeatures['mpg']>=25
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393     True
# 394     True
# 395     True
# 396     True
# 397     True
# Name: mpg, Length: 398, dtype: bool

# %%
carfeatures[carfeatures['mpg']>=25]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 18   27.0          4            97         88    2130          14.5
# 19   26.0          4            97         46    1835          20.5
# 20   25.0          4           110         87    2672          17.5
# 22   25.0          4           104         95    2375          17.5
# 23   26.0          4           121        113    2234          12.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4           140         86    2790          15.6
# 394  44.0          4            97         52    2130          24.6
# 395  32.0          4           135         84    2295          11.6
# 396  28.0          4           120         79    2625          18.6
# 397  31.0          4           119         82    2720          19.4
#
#     vehicle_id  new variable
# 18   D-1689978          27.0
# 19   V-1689989          26.0
# 20   P-1690000          25.0
# 22   S-1690022          25.0
# 23   B-1690033          26.0
# ..         ...           ...
# 393  F-1694103          27.0
# 394  V-1694114          44.0
# 395  D-1694125          32.0
# 396  F-1694136          28.0
# 397  C-1694147          31.0
#
# [169 rows x 8 columns]

# %% [markdown]
# <font size = "4">
#
# Comparing two ```pandas``` series
#
# USE the bitwise operators for ```or``` (```|```) and for ```and``` (```&```) to do element-to-element boolean comparison of a Series

# %%
carfeatures[(carfeatures['acceleration']>=10) & (carfeatures['acceleration']<18)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8           307        130    3504          12.0
# 1    15.0          8           350        165    3693          11.5
# 2    18.0          8           318        150    3436          11.0
# 3    16.0          8           304        150    3433          12.0
# 4    17.0          8           302        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 390  32.0          4           144         96    2665          13.9
# 391  36.0          4           135         84    2370          13.0
# 392  27.0          4           151         90    2950          17.3
# 393  27.0          4           140         86    2790          15.6
# 395  32.0          4           135         84    2295          11.6
#
#     vehicle_id  new variable
# 0    C-1689780          18.0
# 1    B-1689791          15.0
# 2    P-1689802          18.0
# 3    A-1689813          16.0
# 4    F-1689824          17.0
# ..         ...           ...
# 390  T-1694070          32.0
# 391  D-1694081          36.0
# 392  C-1694092          27.0
# 393  F-1694103          27.0
# 395  D-1694125          32.0
#
# [315 rows x 8 columns]

# %% [markdown]
# # Lecture 12: Application 1 - Linear Regression
#
# <font size = "5">
#
# Install the "statsmodels" library
#
# ```conda install statsmodels```

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# We will "alias" two sublibraries in "statsmodels"
# "statsmodels.formula.api" contains functions to estimate models
# "statsmodels.api" contains general-use statistical options

import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# # Generate simulated Data
#
# <font size = "4">
#
# Create an empty dataset

# %%
dataset = pd.DataFrame()

# %% [markdown]
# <font size = "4">
#
# Create two random variables of size ($n = 50$)

# %%
n = 50
np.random.seed(42)
dataset["x"] = np.random.normal(loc = 0,scale = 1, size = n)
dataset["e"] = np.random.normal(loc = 0,scale = 1, size = n)

# %% [markdown]
# <font size = "4">
#
# Create data from the linear model
#
# $ y = b_0 + b_1 x + e, \qquad b_0 = 1, b_1 = 2.$

# %%
# The number b0 is known as the "intercept"
# The number b1 is known as the "slope"

b0 = 1
b1 = 2

# We can compute formulas directly over dataset columns
dataset["y"] = b0 + b1 * dataset["x"] + dataset["e"]

# %%
dataset["y"]
# Out:
# 0     2.317512
# 1     0.338389
# 2     1.618455
# 3     4.657736
# 4     1.562693
# 5     1.463006
# 6     3.319208
# 7     2.225657
# 8     0.392315
# 9     3.060665
# 10   -0.406010
# 11   -0.117118
# 12    0.377590
# 13   -4.022767
# 14   -1.637310
# 15    1.231665
# 16   -1.097672
# 17    2.632028
# 18   -0.454412
# 19   -2.469727
# 20    4.292693
# 21    2.086484
# 22    1.099230
# 23   -0.284853
# 24   -2.708511
# 25    2.043748
# 26   -1.214940
# 27    1.452389
# 28   -0.109517
# 29   -1.570956
# 30   -0.423085
# 31    5.061669
# 32    2.450900
# 33   -1.633692
# 34    1.836596
# 35   -1.943444
# 36    2.333129
# 37   -2.590589
# 38   -2.186132
# 39    1.906990
# 40    2.574011
# 41    2.311382
# 42    0.066650
# 43    0.070130
# 44   -2.349152
# 45   -1.903203
# 46    0.374843
# 47    3.375300
# 48    1.692350
# 49   -2.760667
# Name: y, dtype: float64

# %% [markdown]
# <font size = "4">
#
# Compute the theoretically best fit line
#
# $ p = b_0 + b_1 x$

# %%
dataset["p"] = b0 + b1*dataset["x"]

# %% [markdown]
# <font size = "4">
# Plot the Data

# %%
plt.scatter(x = dataset["x"], y = dataset["y"])
plt.plot(dataset["x"],dataset["p"], color = 'green')

plt.xlabel("X Variable")
plt.ylabel("Y Variable")
plt.legend(labels = ["Data points", "Best fit line"])
plt.show()

# %% [markdown]
# <font size = "5">
# Estimate the Best Fit Line

# %%
# We use the subfunction "ols()" in the library "smf"
#(i) The first argument is a string called "formula" with the format 
#   "outcome ~ indepdent_vars"
#(ii) the second argument is the dataset
model = smf.ols(formula = 'y ~ x', data = dataset)

# The second line fits the model with standard errors "cov"
# In this case we use "robust" standard errors (HC1)
results = model.fit()

# Can also run as one line
# results = smf.ols(formula = 'y ~ x',data = dataset).fit(cov = "HC1")

# %% [markdown]
# <font size = "4">
# Compute the Estimated Best Fit Line

# %%
# We will use ".params" to get the attribute "parameters from the results"

b_list = results.params
print(b_list)

# We can then compute the "estimated" best fit lines
# by extracting the intercept and slop from "b_list"

dataset["p_estimated"] = b_list[0] + b_list[1]  * dataset["x"]

# Note: The estimators for "b0" and "b1" are close to 
# the values we used to generate the data
# Out:
# Intercept    1.041022
# x            2.103076
# dtype: float64
# /var/folders/z7/qqjpryy576j5266kt7vnwcqw0000gn/T/ipykernel_46133/2237251491.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset["p_estimated"] = b_list[0] + b_list[1]  * dataset["x"]

# %% [markdown]
# <font size = "4">
# Plot the Estimated Best Fit Line

# %%
# Use scatter twice, with different "y" inputs
# THe "legend" command creates a box on with the color labels

plt.scatter(x = dataset["x"],y = dataset["y"])
plt.plot(dataset["x"],dataset["p_estimated"], color = 'green')

plt.legend(labels = ["Data points","Estimated Predicted Model"])
plt.show()

# %% [markdown]
# <font size = "4">
# How good is the estimated best fit?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set parameters
n = 50
np.random.seed(42)

# Create the dataset
dataset = pd.DataFrame()
dataset["x"] = np.random.normal(loc=0, scale=1, size=n)
dataset["e"] = np.random.normal(loc=0, scale=1, size=n)

# Create 'p' (actual values) and 'p_estimated' (estimated values)
dataset["p"] = 3 + 2 * dataset["x"] + dataset["e"]  # Actual values
dataset["p_estimated"] = 3 + 2 * dataset["x"]        # Estimated values (without the error term 'e')

# Create a figure for the plot
plt.figure(figsize=(6, 4))

# Sort dataset by x for a better line plot
dataset_sorted = dataset.sort_values("x")

# Plot actual p vs x
plt.plot(dataset_sorted["x"], dataset_sorted["p"], color='blue', label="Actual p", linestyle='-')

# Plot estimated p_estimated vs x
plt.plot(dataset_sorted["x"], dataset_sorted["p_estimated"], color='green', label="Estimated p", linestyle='--')

# Add a legend to label the plots
plt.legend()

# Show the plot
plt.xlabel("x")
plt.ylabel("p / p_estimated")
plt.title("Actual vs Estimated p")

plt.show()
